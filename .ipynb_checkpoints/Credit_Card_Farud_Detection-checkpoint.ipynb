# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report,confusion_matrix,roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import  StratifiedKFold,train_test_split,cross_validate
from imblearn.over_sampling import RandomOverSampler,SMOTE
from imblearn.pipeline import make_pipeline
import xgboost as xgb

import tensorflow as tf
from tensorflow.keras import layers
plt.style.use(['dark_background'])

# %%
df=pd.read_csv('D:\Data\credit_card\creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
not_fraud=(df['Class'].value_counts()[0]/len(df))*100
fraud=(df['Class'].value_counts()[1]/len(df))*100
print(f'Not Fraud: {not_fraud:.2f}% of dataset')
print(f'Fraud: {fraud:.2f}% of dataset')
# Out:
# Not Fraud: 99.83% of dataset
# Fraud: 0.17% of dataset

# %%
sns.countplot('Class',data=df)
plt.title('Class Distributions of Frauds(1) and Not frauds(0)')
# Out:
# Text(0.5, 1.0, 'Class Distributions of Frauds(1) and Not frauds(0)')

# %%
from itertools import combinations

fig, axes = plt.subplots(len(df[:29].columns)//3, 3, figsize=(12, 48))
i = 0
for triaxis in axes:
    for axis in triaxis:
        df.hist(column = df.columns[i], bins = 100, ax=axis)
        i = i+1

# %%
sns.distplot(df['Amount'],bins=50)
# Out:
# <AxesSubplot:xlabel='Amount', ylabel='Density'>

# %% [markdown]
# **Scaling Amount and time features other features are scaled by default**

# %% [markdown]
# **Data Spliting**

# %%
#Randomly suffling data
df=df.sample(frac=1)

# %%
x=df.iloc[:,0:30].values
y=df.iloc[:, 30:].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
y_train=np.ravel(y_train)

# %%
pd.DataFrame(y_train).value_counts()
# Out:
# 0    199029
# 1       335
# dtype: int64

# %%
pd.DataFrame(y_test).value_counts()
# Out:
# 0    85286
# 1      157
# dtype: int64

# %% [markdown]
# # Feature Scaling

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %% [markdown]
# # Random OverSampling

# %% [markdown]
# **It is the process of randamly duplicating sample/rows of Minority classes!**

# %%
#sampling strategy of 0.6 means making  no of rows/sample of minoririty class 60%  of majority class
OverSampler=RandomOverSampler(sampling_strategy=0.6)
os_x_train,os_y_train=OverSampler.fit_resample(x_train,y_train)

# %%
pd.DataFrame(os_y_train).value_counts()
# Out:
# 0    199029
# 1    119417
# dtype: int64

# %% [markdown]
# # SMOTE(Synthetic Minority Over-sampling Technique)

# %% [markdown]
# **It is the process of genrating data for miniority classes!**

# %%
#sampling strategy of 0.6 means making  no of rows/sample of minoririty class 60%  of majority class
smote=SMOTE(sampling_strategy=0.6)
sm_x_train,sm_y_train=smote.fit_resample(x_train,y_train)

# %%
pd.DataFrame(sm_y_train).value_counts()
# Out:
# 0    199029
# 1    119417
# dtype: int64

# %% [markdown]
# # Model Building

# %% [markdown]
# ***We want model to decrease False Negatives (Predcting Fraud as not Fraud) as much as possible. But we also want to make sure there is less False Positive(predicting Not fraud as Fraud) too!***

# %%
def model_report(y_test,y_pred):
    print(f'----Confusion matrix---- \n \n{confusion_matrix(y_test,y_pred)}\n')
    print(classification_report(y_test,y_pred))

# %%
def cross_validation(estimator,cv=StratifiedKFold()):
  #cross validation to make sure result given by the model is just by a chance of train_test_split or not
  scores=cross_validate(estimator,x,np.ravel(y),cv=cv,scoring=['f1','recall'],n_jobs=-1)  
    
  f1_scores=scores['test_f1']
  recall=scores['test_recall']
  print(f'Avg F1 Score:{f1_scores.mean()}\n')
  print(f'Avg Recall Score:{recall.mean()}')

# %% [markdown]
# # Random Forest Classfier

# %% [markdown]
# **With Random Oversampling**

# %%
rf_classifier_os=RandomForestClassifier()
rf_classifier_os.fit(os_x_train,os_y_train)
y_pred=rf_classifier_os.predict(x_test)
model_report(y_test, y_pred)
# Out:
# ----Confusion matrix----
#
# [[85277     9]
#  [   38   119]]
#
# Roc_Auc Score : 0.8789281280774124
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85286
#            1       0.93      0.76      0.84       157
#
#     accuracy                           1.00     85443
#    macro avg       0.96      0.88      0.92     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
imb_pipeline=make_pipeline(RandomOverSampler(sampling_strategy=0.6),RandomForestClassifier())
cross_validation(imb_pipeline)
# Out:
# Avg F1 Score:0.8543096262970856
#
# Avg Recall Score:0.7824572253143682

# %% [markdown]
# **With SMOTE**

# %%
rf_classifier_sm=RandomForestClassifier()
rf_classifier_sm.fit(sm_x_train,sm_y_train)
y_pred=rf_classifier_sm.predict(x_test)
model_report(y_test, y_pred)
# Out:
# ----Confusion matrix----
#
# [[85263    23]
#  [   32   125]]
#
# Roc_Auc Score : 0.8979543315552272
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85286
#            1       0.84      0.80      0.82       157
#
#     accuracy                           1.00     85443
#    macro avg       0.92      0.90      0.91     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
imb_pipeline=make_pipeline(SMOTE(sampling_strategy=0.6),RandomForestClassifier())
cross_validation(imb_pipeline)
# Out:
# Avg F1 Score:0.8587124515453283
#
# Avg Recall Score:0.8291898577612864

# %% [markdown]
# **Random Forest with SMOTE gave more Average Recall and Performed Slightly  better than other models!**

# %% [markdown]
# <h1>Neural Networks</h1>

# %%
model=tf.keras.Sequential([
   layers.Dense(units=65,activation=tf.nn.relu,input_dim=x_train.shape[1]),
   layers.Dropout(0.2),
   layers.Dense(35,activation=tf.nn.relu),
   layers.Dense(1,activation=tf.nn.sigmoid)
  ])
optimizer=tf.keras.optimizers.Adam(0.0001)
model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['Precision','Recall'])

# %%
history=model.fit(x_train,y_train,batch_size=128,epochs=35,validation_data=(x_test,y_test),class_weight={0:1,1:5})
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/35
# 1558/1558 [==============================] - 9s 4ms/step - loss: 0.1293 - precision: 0.0366 - recall: 0.2358 - val_loss: 0.0126 - val_precision: 0.8174 - val_recall: 0.5987
# Epoch 2/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0213 - precision: 0.8409 - recall: 0.6627 - val_loss: 0.0069 - val_precision: 0.8138 - val_recall: 0.7516
# Epoch 3/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0151 - precision: 0.8462 - recall: 0.7552 - val_loss: 0.0058 - val_precision: 0.8108 - val_recall: 0.7643
# Epoch 4/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0127 - precision: 0.8471 - recall: 0.7940 - val_loss: 0.0053 - val_precision: 0.8146 - val_recall: 0.7834
# Epoch 5/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0121 - precision: 0.8396 - recall: 0.7970 - val_loss: 0.0050 - val_precision: 0.8146 - val_recall: 0.7834
# Epoch 6/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0113 - precision: 0.8221 - recall: 0.8000 - val_loss: 0.0050 - val_precision: 0.7799 - val_recall: 0.7898
# Epoch 7/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0108 - precision: 0.8152 - recall: 0.8030 - val_loss: 0.0044 - val_precision: 0.8039 - val_recall: 0.7834
# Epoch 8/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0104 - precision: 0.8198 - recall: 0.8149 - val_loss: 0.0044 - val_precision: 0.7898 - val_recall: 0.7898
# Epoch 9/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0099 - precision: 0.8168 - recall: 0.8119 - val_loss: 0.0045 - val_precision: 0.7764 - val_recall: 0.7962
# Epoch 10/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0096 - precision: 0.8163 - recall: 0.8090 - val_loss: 0.0045 - val_precision: 0.7636 - val_recall: 0.8025
# Epoch 11/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0095 - precision: 0.8088 - recall: 0.8209 - val_loss: 0.0044 - val_precision: 0.7683 - val_recall: 0.8025
# Epoch 12/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0091 - precision: 0.8147 - recall: 0.8269 - val_loss: 0.0041 - val_precision: 0.7962 - val_recall: 0.7962
# Epoch 13/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0088 - precision: 0.8254 - recall: 0.8328 - val_loss: 0.0040 - val_precision: 0.7962 - val_recall: 0.7962
# Epoch 14/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0093 - precision: 0.8265 - recall: 0.8388 - val_loss: 0.0040 - val_precision: 0.7975 - val_recall: 0.8025
# Epoch 15/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0083 - precision: 0.8121 - recall: 0.8388 - val_loss: 0.0039 - val_precision: 0.8025 - val_recall: 0.8025
# Epoch 16/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0087 - precision: 0.8187 - recall: 0.8358 - val_loss: 0.0041 - val_precision: 0.7665 - val_recall: 0.8153
# Epoch 17/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0080 - precision: 0.7977 - recall: 0.8358 - val_loss: 0.0039 - val_precision: 0.7744 - val_recall: 0.8089
# Epoch 18/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0077 - precision: 0.8163 - recall: 0.8358 - val_loss: 0.0040 - val_precision: 0.7665 - val_recall: 0.8153
# Epoch 19/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0082 - precision: 0.8080 - recall: 0.8418 - val_loss: 0.0039 - val_precision: 0.7758 - val_recall: 0.8153
# Epoch 20/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0076 - precision: 0.8208 - recall: 0.8478 - val_loss: 0.0038 - val_precision: 0.7975 - val_recall: 0.8025
# Epoch 21/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0078 - precision: 0.8156 - recall: 0.8448 - val_loss: 0.0036 - val_precision: 0.7937 - val_recall: 0.8089
# Epoch 22/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0074 - precision: 0.8206 - recall: 0.8328 - val_loss: 0.0039 - val_precision: 0.7619 - val_recall: 0.8153
# Epoch 23/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0076 - precision: 0.8132 - recall: 0.8448 - val_loss: 0.0039 - val_precision: 0.7574 - val_recall: 0.8153
# Epoch 24/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0075 - precision: 0.7989 - recall: 0.8418 - val_loss: 0.0039 - val_precision: 0.7619 - val_recall: 0.8153
# Epoch 25/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0068 - precision: 0.8023 - recall: 0.8478 - val_loss: 0.0036 - val_precision: 0.7805 - val_recall: 0.8153
# Epoch 26/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0069 - precision: 0.8143 - recall: 0.8507 - val_loss: 0.0037 - val_precision: 0.7805 - val_recall: 0.8153
# Epoch 27/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0069 - precision: 0.8097 - recall: 0.8507 - val_loss: 0.0037 - val_precision: 0.7805 - val_recall: 0.8153
# Epoch 28/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0069 - precision: 0.8242 - recall: 0.8537 - val_loss: 0.0037 - val_precision: 0.7619 - val_recall: 0.8153
# Epoch 29/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0068 - precision: 0.8090 - recall: 0.8597 - val_loss: 0.0039 - val_precision: 0.7574 - val_recall: 0.8153
# Epoch 30/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0066 - precision: 0.8000 - recall: 0.8597 - val_loss: 0.0036 - val_precision: 0.7853 - val_recall: 0.8153
# Epoch 31/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0070 - precision: 0.8091 - recall: 0.8478 - val_loss: 0.0037 - val_precision: 0.7758 - val_recall: 0.8153
# Epoch 32/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0064 - precision: 0.8074 - recall: 0.8507 - val_loss: 0.0037 - val_precision: 0.7711 - val_recall: 0.8153
# Epoch 33/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0064 - precision: 0.8153 - recall: 0.8567 - val_loss: 0.0035 - val_precision: 0.7950 - val_recall: 0.8153
# Epoch 34/35
# 1558/1558 [==============================] - 7s 4ms/step - loss: 0.0060 - precision: 0.8118 - recall: 0.8627 - val_loss: 0.0035 - val_precision: 0.7950 - val_recall: 0.8153
# Epoch 35/35
# 1558/1558 [==============================] - 6s 4ms/step - loss: 0.0063 - precision: 0.8148 - recall: 0.8537 - val_loss: 0.0036 - val_precision: 0.7805 - val_recall: 0.8153

# %% [markdown]
# **Model Evaluation**

# %%
def compute_f1score(precision,recall):
  f1_score=(2*precision*recall)/(precision+recall)
  return f1_score

#Retriving loss,precision,recall from History
loss=history.history['loss']
val_loss=history.history['val_loss']

precision=np.array(history.history['precision'])
recall=np.array(history.history['recall'])
f1_score=compute_f1score(precision,recall)

val_precision=np.array(history.history['val_precision'])
val_recall=np.array(history.history['val_recall'])
val_f1_score=compute_f1score(val_precision,val_recall)

epochs=range(len(loss))

# %%
#ploting training and validation loss
plt.plot(epochs,loss,label='Training Loss')
plt.plot(epochs,val_loss,label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.yscale('log')
plt.legend()
plt.show()

#ploting training and validation F1Score
plt.plot(epochs,f1_score,label='Training F1Score')
plt.plot(epochs,val_f1_score,label='Validation F1Score')
plt.title('Training and Validation F1Score')
plt.xlabel('Epochs')
#plt.yscale('log')
plt.legend()
plt.show()

# %%
y_pred=model.predict_classes(x_test)
model_report(y_test,y_pred)
# Out:
# ----Confusion matrix----
#
# [[85250    36]
#  [   29   128]]
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85286
#            1       0.78      0.82      0.80       157
#
#     accuracy                           1.00     85443
#    macro avg       0.89      0.91      0.90     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# **Random Forest with SMOTE gave more Average Recall and Performed Slightly  better than other models!**
